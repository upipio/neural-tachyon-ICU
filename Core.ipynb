# %%
# Re-implmentation of AI Clinician Matlab Code in Python 
# Author: KyungJoong Kim (GIST, South Korea)
# Date: 2020 June 2 
# 
# This code is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY;
# without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE


# Note 
#
# K-Means in scikit-learn will produce differnt outcome with Matlab's original K-means 
# The random number generator will produce different random number sequence 
# 
# Todo: 
# eICU was not included in this re-implementation 





## AI Clinician core code

# (c) Matthieu Komorowski, Imperial College London 2015-2019
# as seen in publication: https://www.nature.com/articles/s41591-018-0213-5

# version 16 Feb 19
# Builds 500 models using MIMIC-III training data
# Records best candidate models along the way from off-policy policy evaluation on MIMIC-III validation data
# Tests the best model on eRI data


# TAKES:
        # MIMICtable = m*59 table with raw values from MIMIC
        # eICUtable = n*56 table with raw values from eICU
        

# GENERATES:
        # MIMICraw = MIMIC RAW DATA m*47 array with columns in right order
        # MIMICzs = MIMIC ZSCORED m*47 array with columns in right order, matching MIMICraw
        # eICUraw = eICU RAW DATA n*47 array with columns in right order, matching MIMICraw
        # eICUzs = eICU ZSCORED n*47 array with columns in right order, matching MIMICraw
        # recqvi = summary statistics of all 500 models
        # idxs = state membership of MIMIC test records, for all 500 models
     	# OA = optimal policy, for all 500 models
        # allpols = detailed data about the best candidate models

# This code is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY;
# without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE

# Note: The size of the cohort will depend on which version of MIMIC-III is used.
# The original cohort from the 2018 Nature Medicine publication was built using MIMIC-III v1.3.

import pickle 
import numpy as np 
import pandas as pd 
from scipy.stats import zscore, rankdata
import math 
import scipy.io as sio 
import datetime 
from scipy.stats.mstats import mquantiles
from mdptoolbox.mdp import PolicyIteration
from reinforcement_learning_mp import offpolicy_multiple_eval_010518
from kmeans_mp import kmeans_with_multiple_runs 
from multiprocessing import freeze_support 

def my_zscore(x):
    return zscore(x,ddof=1),np.mean(x,axis=0),np.std(x,axis=0,ddof=1)

# %%
######### Functions used in Reinforcement Learning ######## 


class PolicyIteration_with_Q(PolicyIteration):
    def __init__(self, transitions, reward, discount, policy0=None,max_iter=1000, eval_type=0, skip_check=False):
        # Python MDP toolbox from https://github.com/sawcordwell/pymdptoolbox
        # In Matlab MDP Toolbox, P = (S, S, A), R = (S, A) 
        # In Python MDP Toolbox, P = (A, S, S), R= (S, A)

        transitions = np.transpose(transitions,(2,0,1)).copy() # Change to Action First (A, S, S)
        skip_check = True # To Avoid StochasticError: 'PyMDPToolbox - The transition probability matrix is not stochastic.'

        PolicyIteration.__init__(self, transitions, reward, discount, policy0=None,max_iter=1000, eval_type=0, skip_check=skip_check)
    
    def _bellmanOperator_with_Q(self, V=None):
        # Apply the Bellman operator on the value function.
        #
        # Updates the value function and the Vprev-improving policy.
        #
        # Returns: (policy, Q, value), tuple of new policy and its value
        #
        # If V hasn't been sent into the method, then we assume to be working
        # on the objects V attribute
        if V is None:
            # this V should be a reference to the data rather than a copy
            V = self.V
        else:
            # make sure the user supplied V is of the right shape
            try:
                assert V.shape in ((self.S,), (1, self.S)), "V is not the " \
                    "right shape (Bellman operator)."
            except AttributeError:
                raise TypeError("V must be a numpy array or matrix.")
        # Looping through each action the the Q-value matrix is calculated.
        # P and V can be any object that supports indexing, so it is important
        # that you know they define a valid MDP before calling the
        # _bellmanOperator method. Otherwise the results will be meaningless.
        Q = np.empty((self.A, self.S))
        for aa in range(self.A):
            Q[aa] = self.R[aa] + self.discount * self.P[aa].dot(V)
        # Get the policy and value, for now it is being returned but...
        # Which way is better?
        # 1. Return, (policy, value)
        return (Q.argmax(axis=0), Q, Q.max(axis=0))
        # 2. update self.policy and self.V directly
        # self.V = Q.max(axis=1)
        # self.policy = Q.argmax(axis=1)
    
    def run(self):
        # Run the policy iteration algorithm.
        self._startRun()

        while True:
            self.iter += 1
            # these _evalPolicy* functions will update the classes value
            # attribute
            if self.eval_type == "matrix":
                self._evalPolicyMatrix()
            elif self.eval_type == "iterative":
                self._evalPolicyIterative()
            # This should update the classes policy attribute but leave the
            # value alone
            policy_next, Q, null = self._bellmanOperator_with_Q()
            del null
            # calculate in how many places does the old policy disagree with
            # the new policy
            n_different = (policy_next != self.policy).sum()
            # if verbose then continue printing a table
            if self.verbose:
                _printVerbosity(self.iter, n_different)
            # Once the policy is unchanging of the maximum number of
            # of iterations has been reached then stop
            if n_different == 0:
                if self.verbose:
                    print(_MSG_STOP_UNCHANGING_POLICY)
                break
            elif self.iter == self.max_iter:
                if self.verbose:
                    print(_MSG_STOP_MAX_ITER)
                break
            elif self.iter > 20 and n_different <=5 : # This condition was added from the Nature Code 
                if self.verbose: 
                    print((_MSG_STOP))
                break 
            else:
                self.policy = policy_next

        self._endRun()
        
        return Q

# %%
if __name__ == '__main__': 
    
    freeze_support()
    
    # To ignore 'Runtime Warning: Invalid value encountered in greater' caused by NaN
    # np.warnings.filterwarnings('ignore') (diganti dengan kode dibawha untuk warning)
    import warnings
    warnings.filterwarnings('ignore')
    # --- PERBAIKAN 1 ---
    # Load pickle 
    with open('step_4_start.pkl', 'rb') as file:
        MIMICtable = pickle.load(file)
    
    # --- PERBAIKAN 2: Membersihkan Nama Kolom (CRITICAL) ---
    # Menghapus tanda kutip yang tidak sengaja terbawa di nama kolom
    # Ini yang bikin baris ke-44 error sebelumnya
    MIMICtable.columns = MIMICtable.columns.str.replace("'", "")
    
    #############################  MODEL PARAMETERS   #####################################

    print('####  INITIALISATION  ####') 

    nr_reps=500               # nr of repetitions (total nr models) % 500 
    nclustering=32            # how many times we do clustering (best solution will be chosen) % 32
    prop=0.25                 # proportion of the data we sample for clustering
    gamma=0.99                # gamma
    transthres=5              # threshold for pruning the transition matrix
    polkeep=1                 # count of saved policies
    ncl=750                   # nr of states
    nra=5                     # nr of actions (2 to 10)
    ncv=5                     # nr of crossvalidation runs (each is 80% training / 20% test)
    OA=np.full((752,nr_reps),np.nan)       # record of optimal actions
    recqvi=np.full((nr_reps*2,30),np.nan)  # saves data about each model (1 row per model)
    # allpols=[]  # saving best candidate models
    
    
    # #################   Convert training data and compute conversion factors    ######################

    # all 47 columns of interest
    colbin = ['gender','mechvent','max_dose_vaso','re_admission'] 
    colnorm= ['age','Weight_kg','GCS','HR','SysBP','MeanBP','DiaBP','RR','Temp_C','FiO2_1',\
        'Potassium','Sodium','Chloride','Glucose','Magnesium','Calcium',\
        'Hb','WBC_count','Platelets_count','PTT','PT','Arterial_pH','paO2','paCO2',\
        'Arterial_BE','HCO3','Arterial_lactate','SOFA','SIRS','Shock_Index','PaO2_FiO2','cumulated_balance'] 
    collog=['SpO2','BUN','Creatinine','SGOT','SGPT','Total_bili','INR','input_total','input_4hourly','output_total','output_4hourly']

    colbin=np.where(np.isin(MIMICtable.columns,colbin))[0]
    colnorm=np.where(np.isin(MIMICtable.columns,colnorm))[0]
    collog=np.where(np.isin(MIMICtable.columns,collog))[0]

    # find patients who died in ICU during data collection period
    # ii=MIMICtable.bloc==1&MIMICtable.died_within_48h_of_out_time==1& MIMICtable.delay_end_of_record_and_discharge_or_death<24;
    # icustayidlist=MIMICtable.icustayid;
    # ikeep=~ismember(icustayidlist,MIMICtable.icustayid(ii));
    reformat5=MIMICtable.values.copy() 
    # reformat5=reformat5(ikeep,:);
    icustayidlist=MIMICtable['icustayid']
    icuuniqueids=np.unique(icustayidlist) # list of unique icustayids from MIMIC
    idxs=np.full((icustayidlist.shape[0],nr_reps),np.nan) # record state membership test cohort

    MIMICraw=MIMICtable.iloc[:, np.concatenate([colbin,colnorm,collog])] 
    MIMICraw=MIMICraw.values.copy()  # RAW values
    MIMICzs=np.concatenate([reformat5[:, colbin]-0.5, zscore(reformat5[:,colnorm],ddof=1), zscore(np.log(0.1+reformat5[:, collog]),ddof=1)],axis=1)
    
    # --- PERBAIKAN 3: Bersihkan NaN sebelum diproses ---
    # Scikit-learn terbaru akan crash jika ada NaN. 
    # Kita ubah NaN jadi 0 (karena ini data Z-score, 0 = nilai rata-rata).
    # Ini aman dan tidak merusak logika statistik.
    MIMICzs = np.nan_to_num(MIMICzs)

    MIMICzs[:,3]=np.log(MIMICzs[:,3]+0.6)
    
    #MIMICzs[:,3]=np.log(MIMICzs[:,3]+0.6)   # MAX DOSE NORAD 
    
    # --- PERBAIKAN 4: UN-COMMENT BARIS INI ---
    # Karena nama kolom sudah diperbaiki di atas, baris ini HARUSNYA sudah aman.
    # Jangan di-comment, karena ini logika penting (memberi bobot lebih pada input).
    if MIMICzs.shape[1] > 44:
        MIMICzs[:,44]=2*MIMICzs[:,44]   
    else:
        print("Warning: Kolom 44 masih tidak ditemukan, skip weighting.")
    
    # MIMICzs[:,44]=2*MIMICzs[:,44]   # increase weight of this variable (MIMICzs yang berhasil dibuat hanya punya 24 kolom. Jadi index 44 tidak ada, 


    # eICU section was not implemented 
    
    # compute conversion factors using MIMIC data
    a=MIMICraw[:, 0:3]-0.5 
    b= np.log(MIMICraw[:,3]+0.1)
    c,cmu,csigma = my_zscore(MIMICraw[:,4:36])
    d,dmu,dsigma = my_zscore(np.log(0.1+MIMICraw[:,36:47]))
    

    ####################### Main LOOP ###########################
    bestpol = 0 
    
    for modl in range(nr_reps):  # MAIN LOOP OVER ALL MODELS
        N=icuuniqueids.size # total number of rows to choose from
        grp=np.floor(ncv*np.random.rand(N,1)+1);  #list of 1 to 5 (20% of the data in each grp) -- this means that train/test MIMIC split are DIFFERENT in all the 500 models
        crossval=1;
        trainidx=icuuniqueids[np.where(grp!=crossval)[0]]
        testidx=icuuniqueids[np.where(grp==crossval)[0]]
        train=np.isin(icustayidlist,trainidx)
        test=np.isin(icustayidlist,testidx)
        X=MIMICzs[train,:]
        Xtestmimic=MIMICzs[~train,:]
        blocs=reformat5[train,0]
        bloctestmimic=reformat5[~train,0]
        ptid=reformat5[train,1]
        ptidtestmimic=reformat5[~train,1] 
        outcome=9 #   HOSP _ MORTALITY = 7 / 90d MORTA = 9
        
        # --- PERBAIKAN 5: Masalah ValueError NaN di Target (Y90) ---
        # Kita ambil data outcome, lalu kita ubah NaN jadi 0 (Survival)
        Y90raw = reformat5[train,outcome]
        Y90 = np.nan_to_num(Y90raw, nan=0.0)
        
        # Y90=reformat5[train,outcome];   


        print('########################   MODEL NUMBER : ',modl)
        print(datetime.datetime.now())

        #######   find best clustering solution (lowest intracluster variability)  ####################
        print('####  CLUSTERING  ####') # BY SAMPLING
        N=X.shape[0] #total number of rows to choose from
        sampl=X[np.where(np.floor(np.random.rand(N,1)+prop))[0],:]

        C = kmeans_with_multiple_runs(ncl,10000,nclustering,sampl) 
        idx = C.predict(X)

        ############################## CREATE ACTIONS  ########################
        print('####  CREATE ACTIONS  ####') 

        nact=nra*nra

        iol=MIMICtable.columns.get_loc('input_4hourly') 
        vcl=MIMICtable.columns.get_loc('max_dose_vaso') 

        a= reformat5[:,iol].copy()                   # IV fluid
        a= rankdata(a[a>0])/a[a>0].shape[0]   # excludes zero fluid (will be action 1)

        iof=np.floor((a+0.2499999999)*4)  #converts iv volume in 4 actions

        a= reformat5[:,iol].copy() 
        a= np.where(a>0)[0]  # location of non-zero fluid in big matrix

        io=np.ones((reformat5.shape[0],1))  # array of ones, by default     
        io[a]=(iof+1).reshape(-1,1)   # where more than zero fluid given: save actual action
        io = io.ravel() 

        vc=reformat5[:,vcl].copy() 
        vcr= rankdata(vc[vc!=0])/vc[vc!=0].size
        vcr=np.floor((vcr+0.249999999999)*4)  # converts to 4 bins
        vcr[vcr==0]=1
        vc[vc!=0]=vcr+1 
        vc[vc==0]=1

        # PERBAIKAN 6: Amankan perhitungan Median Action dari NaN
        # (Jaga-jaga jika ada subset action yang kosong)
        ma1_list = []
        for i in range(1, 6):
            subset = reformat5[io==i, iol]
            val = np.median(subset) if len(subset) > 0 else 0
            ma1_list.append(val)
        ma1 = np.array(ma1_list)

        ma2_list = []
        for i in range(1, 6):
            subset = reformat5[vc==i, vcl]
            val = np.median(subset) if len(subset) > 0 else 0
            ma2_list.append(val)
        ma2 = np.array(ma2_list)

        #ma1 = np.array([np.median(reformat5[io==1,iol]),np.median(reformat5[io==2,iol]),np.median(reformat5[io==3,iol]), np.median(reformat5[io==4,iol]),np.median(reformat5[io==5,iol])]) # median dose of drug in all bins
        #ma2 = np.array([np.median(reformat5[vc==1,vcl]),np.median(reformat5[vc==2,vcl]),np.median(reformat5[vc==3,vcl]), np.median(reformat5[vc==4,vcl]),np.median(reformat5[vc==5,vcl])])

        med = np.concatenate([io.reshape(-1,1),vc.reshape(-1,1)],axis=1)
        uniqueValues,actionbloc = np.unique(med,axis=0,return_inverse=True)

        actionbloctrain=actionbloc[train] 

        ma2Values = ma2[uniqueValues[:,1].astype('int64')-1].reshape(-1,1)
        ma1Values = ma1[uniqueValues[:,0].astype('int64')-1].reshape(-1,1)

        uniqueValuesdose = np.concatenate([ma2Values,ma1Values],axis=1) # median dose of each bin for all 25 actions 

        ####################################################################################################################################
        print('####  CREATE QLDATA3  ####')

        r=np.array([100, -100]).reshape(1,-1)
        r2=r*(2*(1-Y90.reshape(-1,1))-1)
        # because idx and actionbloctrain are index, it's equal to (Matlab's original value -1)
        qldata=np.concatenate([blocs.reshape(-1,1), idx.reshape(-1,1), actionbloctrain.reshape(-1,1), Y90.reshape(-1,1), r2],axis=1)  # contains bloc / state / action / outcome&reward     
        # 0 = died in Python, 1 = died in Matlab 
        qldata3=np.zeros((np.floor(qldata.shape[0]*1.2).astype('int64'),4))
        c=-1
        abss=np.array([ncl+1, ncl]) #absorbing states numbers # 751, 750 

        for i in range(qldata.shape[0]-1):
            c=c+1
            qldata3[c,:]=qldata[i,0:4] 
            if(qldata[i+1,0]==1): #end of trace for this patient
                c=c+1
                # DI SINI YANG TADI ERROR.
                # Sekarang qldata[i,3] (Y90) sudah bersih dari NaN, jadi aman di-int()
                qldata3[c,:]=np.array([qldata[i,0]+1, abss[int(qldata[i,3])], -1, qldata[i,4]]) 

        qldata3=qldata3[:c+1,:]


        # ###################################################################################################################################
        print("####  CREATE TRANSITION MATRIX T(S'',S,A) ####")
        transitionr=np.zeros((ncl+2,ncl+2,nact))  #this is T(S',S,A)
        sums0a0=np.zeros((ncl+2,nact)) 

        for i in range(qldata3.shape[0]-1):    
            if (qldata3[i+1,0]!=1) : # if we are not in the last state for this patient = if there is a transition to make!
                S0=int(qldata3[i,1]) 
                S1=int(qldata3[i+1,1])
                acid= int(qldata3[i,2]) 
                transitionr[S1,S0,acid]=transitionr[S1,S0,acid]+1 
                sums0a0[S0,acid]=sums0a0[S0,acid]+1

        sums0a0[sums0a0<=transthres]=0  #delete rare transitions (those seen less than 5 times = bottom 50%!!)

        for i in range(ncl+2): 
            for j in range(nact): 
                if sums0a0[i,j]==0: 
                    transitionr[:,i,j]=0; 
                else:
                    transitionr[:,i,j]=transitionr[:,i,j]/sums0a0[i,j]


        transitionr[np.isnan(transitionr)]=0  #replace NANs with zeros
        transitionr[np.isinf(transitionr)]=0  #replace NANs with zeros

        physpol=sums0a0/np.sum(sums0a0, axis=1).reshape(-1,1)    #physicians policy: what action was chosen in each state


        print("####  CREATE TRANSITION MATRIX T(S,S'',A)  ####")

        transitionr2=np.zeros((ncl+2,ncl+2,nact))  # this is T(S,S',A)
        sums0a0=np.zeros((ncl+2,nact))

        for i in range(qldata3.shape[0]-1) : 
            if (qldata3[i+1,0]!=1) : # if we are not in the last state for this patient = if there is a transition to make!
                S0=int(qldata3[i,1])
                S1=int(qldata3[i+1,1])
                acid= int(qldata3[i,2]) 
                transitionr2[S0,S1,acid]=transitionr2[S0,S1,acid]+1;  
                sums0a0[S0,acid]=sums0a0[S0,acid]+1

        sums0a0[sums0a0<=transthres]=0;  #delete rare transitions (those seen less than 5 times = bottom 50%!!) IQR = 2-17

        for i in range(ncl+2): 
            for j in range(nact): 
                if sums0a0[i,j]==0:
                    transitionr2[i,:,j]=0 
                else: 
                    transitionr2[i,:,j]=transitionr2[i,:,j]/sums0a0[i,j]

        transitionr2[np.isnan(transitionr2)]=0 #replace NANs with zeros
        transitionr2[np.isinf(transitionr2)]=0 # replace infs with zeros

        print('####  CREATE REWARD MATRIX  R(S,A) ####')
        # CF sutton& barto bottom 1998 page 106. i compute R(S,A) from R(S'SA) and T(S'SA)
        r3=np.zeros((ncl+2,ncl+2,nact))
        r3[ncl,:,:]=-100
        r3[ncl+1,:,:]=100
        R=sum(transitionr*r3)
        R=np.squeeze(R)   #remove 1 unused dimension


        print('####  POLICY ITERATION   ####')


        pi = PolicyIteration_with_Q(transitionr2, R, gamma, np.ones((ncl+2,1))) 
        Qon = np.transpose(pi.run()) 
        OptimalAction=np.argmax(Qon,axis=1).reshape(-1,1)  #deterministic 
        OA[:,modl]=OptimalAction.ravel() #save optimal actions


        print('####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####')
        # create new version of QLDATA3

        r=np.array([100, -100]).reshape(1,-1)
        r2=r*(2*(1-Y90.reshape(-1,1))-1)
        # because idx and actionbloctrain are index, it's equal to (Matlab's original value -1)
        qldata=np.concatenate([blocs.reshape(-1,1), idx.reshape(-1,1), actionbloctrain.reshape(-1,1), Y90.reshape(-1,1),np.zeros((idx.size,1)), r2[:,0].reshape(-1,1), ptid.reshape(-1,1) ],axis=1)   # contains bloc / state / action / outcome&reward     
        # 0 = died in Python, 1 = died in Matlab 
        qldata3=np.zeros((np.floor(qldata.shape[0]*1.2).astype('int64'),8))
        c=-1
        abss=np.array([ncl+1, ncl]) #absorbing states numbers # 751, 750 

        for i in range(qldata.shape[0]-1):
            c=c+1
            qldata3[c,:]=qldata[i,[0,1,2,4,6,6,6,6]] 
            if(qldata[i+1,0]==1): #end of trace for this patient
                c=c+1     
                qldata3[c,:]=np.array([qldata[i,0]+1, abss[int(qldata[i,3])], -1, qldata[i,5],0,0,-1,qldata[i,6]]) 

        qldata3=qldata3[:c+1,:]

        #  add pi(s,a) and b(s,a)
        p=0.01 #softening policies 
        softpi=physpol.copy() # behavior policy = clinicians' 
        for i in range(ncl): 
            ii=softpi[i,:]==0    
            z=p/sum(ii)    
            nz=p/sum(~ii)    
            softpi[i,ii]=z;   
            softpi[i,~ii]=softpi[i,~ii]-nz;

        softb=np.abs(np.zeros((ncl+2,nact))-p/24) #"optimal" policy = target policy = evaluation policy 

        for i in range(ncl): 
            softb[i,OptimalAction[i]]=1-p


        for i in range(qldata3.shape[0]):  # adding the probas of policies to qldata3
            if qldata3[i,1]<ncl :
                qldata3[i,4]=softpi[int(qldata3[i,1]),int(qldata3[i,2])]
                qldata3[i,5]=softb[int(qldata3[i,1]),int(qldata3[i,2])]
                qldata3[i,6]=OptimalAction[int(qldata3[i,1])]  #optimal action

        qldata3train=qldata3.copy() 


        bootql,bootwis = offpolicy_multiple_eval_010518(qldata3,physpol, 0.99,1,6,750)

        recqvi[modl,0]=modl
        recqvi[modl,3]=np.nanmean(bootql)
        recqvi[modl,4]=mquantiles(bootql,0.99, alphap=0.5, betap=0.5)[0]
        recqvi[modl,5]=np.nanmean(bootwis) # we want this as high as possible
        recqvi[modl,6]=mquantiles(bootwis,0.05, alphap=0.5, betap=0.5)[0] #we want this as high as possible


        # testing on MIMIC-test
        print('####  OFF-POLICY EVALUATION - MIMIC TEST SET ####')

        # create new version of QLDATA3 with MIMIC TEST samples

        idxtest = C.predict(Xtestmimic)

        idxs[test,modl]=idxtest.ravel()  #important: record state membership of test cohort

        actionbloctest=actionbloc[~train]
        
        # --- PERBAIKAN 7: Masalah NaN juga di Test Set (Y90test) ---
        Y90testRaw = reformat5[~train,outcome]
        Y90test = np.nan_to_num(Y90testRaw, nan=0.0) # Bersihkan NaN
        
        #Y90test=reformat5[~train,outcome]

        r=np.array([100, -100]).reshape(1,-1)
        r2=r*(2*(1-Y90test.reshape(-1,1))-1)
        # because idx and actionbloctrain are index, it's equal to (Matlab's original value -1)

        qldata=np.concatenate([bloctestmimic.reshape(-1,1), idxtest.reshape(-1,1), actionbloctest.reshape(-1,1), Y90test.reshape(-1,1),np.zeros((idxtest.size,1)), r2[:,0].reshape(-1,1), ptidtestmimic.reshape(-1,1) ],axis=1)   # contains bloc / state / action / outcome&reward     
        # 0 = died in Python, 1 = died in Matlab 
        qldata3=np.zeros((np.floor(qldata.shape[0]*1.2).astype('int64'),8))
        c=-1
        abss=np.array([ncl+1, ncl]) #absorbing states numbers # 751, 750 

        for i in range(qldata.shape[0]-1):
            c=c+1
            qldata3[c,:]=qldata[i,[0,1,2,4,6,6,6,6]] 
            if(qldata[i+1,0]==1): #end of trace for this patient
                c=c+1
                # Ini juga aman sekarang
                qldata3[c,:]=np.array([qldata[i,0]+1, abss[int(qldata[i,3])], -1, qldata[i,5],0,0,-1,qldata[i,6]]) 

        qldata3=qldata3[:c+1,:]

        #  add pi(s,a) and b(s,a)
        p=0.01 # small correction factor #softening policies 
        softpi=physpol.copy() # behavior policy = clinicians' 
        for i in range(ncl): 
            ii=softpi[i,:]==0    
            z=p/sum(ii)    
            nz=p/sum(~ii)    
            softpi[i,ii]=z;   
            softpi[i,~ii]=softpi[i,~ii]-nz;

        softb=np.abs(np.zeros((ncl+2,nact))-p/24) #"optimal" policy = target policy = evaluation policy 

        for i in range(ncl): 
            softb[i,OptimalAction[i]]=1-p

        for i in range(qldata3.shape[0]):  # adding the probas of policies to qldata3
            if qldata3[i,1]<ncl :
                qldata3[i,4]=softpi[int(qldata3[i,1]),int(qldata3[i,2])]
                qldata3[i,5]=softb[int(qldata3[i,1]),int(qldata3[i,2])]
                qldata3[i,6]=OptimalAction[int(qldata3[i,1])]  #optimal action

        qldata3test=qldata3.copy() 

        bootmimictestql,bootmimictestwis = offpolicy_multiple_eval_010518(qldata3,physpol, 0.99,1,6,2000)

        recqvi[modl,18]=mquantiles(bootmimictestql,0.95, alphap=0.5, betap=0.5)[0] #PHYSICIANS' 95% UB
        recqvi[modl,19]=np.nanmean(bootmimictestql)
        recqvi[modl,20]=mquantiles(bootmimictestql,0.99, alphap=0.5, betap=0.5)[0]
        recqvi[modl,21]=np.nanmean(bootmimictestwis) 
        recqvi[modl,22]=mquantiles(bootmimictestwis,0.01, alphap=0.5, betap=0.5)[0] 
        recqvi[modl,23]=mquantiles(bootmimictestwis,0.05, alphap=0.5, betap=0.5)[0] #AI 95% LB, we want this as high as possible




        if recqvi[modl,23] > 40: #saves time if policy is not good on MIMIC test: skips to next model
            print('########################## eICU TEST SET #############################')
            # eICU part was not implemented 



        # eICU testing was not included 
        if recqvi[modl,23]>0 : #  & recqvi(modl,14)>0   # if 95% LB is >0 : save the model (otherwise it's pointless)
            print('####   GOOD MODEL FOUND - SAVING IT   ####' ) 

            # best pol 
            if(bestpol < recqvi[modl,23]):
                print('Best policy was replaced => 95% LB is ',recqvi[modl,23])
                bestpol = recqvi[modl,23] 
                
                # save to pickle 
                with open('bestpol.pkl', 'wb') as file:
                    pickle.dump(modl,file)
                    pickle.dump(Qon,file)
                    pickle.dump(physpol,file)
                    pickle.dump(transitionr,file) 
                    pickle.dump(transitionr2,file)
                    pickle.dump(R,file)
                    pickle.dump(C,file)
                    pickle.dump(train,file)
                    pickle.dump(qldata3train,file)
                    pickle.dump(qldata3test,file) 


    recqvi=recqvi[:modl+1,:]

    # save to pickle for visualization 
    with open('step_5_start.pkl', 'wb') as file:
        pickle.dump(MIMICzs,file)
        pickle.dump(actionbloc,file)
        pickle.dump(reformat5,file)
        pickle.dump(recqvi,file)

    # save recqvi in csv format 
    np.savetxt('recqvi.csv',recqvi,delimiter=',')
# Out:
# ####  INITIALISATION  ####
# Warning: Kolom 44 masih tidak ditemukan, skip weighting.
# ########################   MODEL NUMBER :  0
# 2025-12-01 23:12:11.115050
# ####  CLUSTERING  ####
# The best inertia =  78295.81286917982
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.502234
#
#    Mean value of AI policy by WIS : 95.234273
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.214110
#
#    Mean value of AI policy by WIS : 1.888956
#
# ########################   MODEL NUMBER :  1
# 2025-12-01 23:13:45.492652
# ####  CLUSTERING  ####
# The best inertia =  77559.9694422442
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.714943
#
#    Mean value of AI policy by WIS : 90.445224
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.554352
#
#    Mean value of AI policy by WIS : 86.814593
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# Best policy was replaced => 95% LB is  70.503652963342
# ########################   MODEL NUMBER :  2
# 2025-12-01 23:15:20.373735
# ####  CLUSTERING  ####
# The best inertia =  76990.04618644333
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.684715
#
#    Mean value of AI policy by WIS : 85.679351
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.394591
#
#    Mean value of AI policy by WIS : 84.142050
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# Best policy was replaced => 95% LB is  82.61686238355865
# ########################   MODEL NUMBER :  3
# 2025-12-01 23:16:57.983748
# ####  CLUSTERING  ####
# The best inertia =  76719.8337200372
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.128713
#
#    Mean value of AI policy by WIS : 90.555918
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.566277
#
#    Mean value of AI policy by WIS : 87.031565
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  4
# 2025-12-01 23:18:42.334067
# ####  CLUSTERING  ####
# The best inertia =  77787.35529062069
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.435141
#
#    Mean value of AI policy by WIS : 89.863071
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.836767
#
#    Mean value of AI policy by WIS : 61.328279
#
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  5
# 2025-12-01 23:20:25.985754
# ####  CLUSTERING  ####
# The best inertia =  77776.43749522984
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.125036
#
#    Mean value of AI policy by WIS : 83.201821
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.662098
#
#    Mean value of AI policy by WIS : 84.238876
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# Best policy was replaced => 95% LB is  82.67267159229309
# ########################   MODEL NUMBER :  6
# 2025-12-01 23:22:12.514492
# ####  CLUSTERING  ####
# The best inertia =  77269.91233670509
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.848414
#
#    Mean value of AI policy by WIS : 87.025312
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.154117
#
#    Mean value of AI policy by WIS : 90.667192
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# Best policy was replaced => 95% LB is  86.8776401649663
# ########################   MODEL NUMBER :  7
# 2025-12-01 23:23:54.977065
# ####  CLUSTERING  ####
# The best inertia =  78476.01139105244
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.091996
#
#    Mean value of AI policy by WIS : 85.492789
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 55.835616
#
#    Mean value of AI policy by WIS : 90.548744
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  8
# 2025-12-01 23:25:40.926176
# ####  CLUSTERING  ####
# The best inertia =  77492.64594889697
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.104603
#
#    Mean value of AI policy by WIS : 86.327271
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.665746
#
#    Mean value of AI policy by WIS : 90.672887
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# Best policy was replaced => 95% LB is  90.1012482250637
# ########################   MODEL NUMBER :  9
# 2025-12-01 23:27:25.976485
# ####  CLUSTERING  ####
# The best inertia =  77511.0435912697
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.881384
#
#    Mean value of AI policy by WIS : 85.662648
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.644413
#
#    Mean value of AI policy by WIS : 82.670448
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  10
# 2025-12-01 23:29:11.575180
# ####  CLUSTERING  ####
# The best inertia =  78029.19731734169
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.723453
#
#    Mean value of AI policy by WIS : 88.497852
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.146771
#
#    Mean value of AI policy by WIS : 90.359012
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# Best policy was replaced => 95% LB is  90.1500130241319
# ########################   MODEL NUMBER :  11
# 2025-12-01 23:30:58.822543
# ####  CLUSTERING  ####
# The best inertia =  77627.80594875071
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.119158
#
#    Mean value of AI policy by WIS : 91.069998
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 55.931540
#
#    Mean value of AI policy by WIS : 86.733435
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  12
# 2025-12-01 23:32:41.092843
# ####  CLUSTERING  ####
# The best inertia =  76860.35512473405
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 58.498728
#
#    Mean value of AI policy by WIS : 83.192649
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 62.248156
#
#    Mean value of AI policy by WIS : 91.491096
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  13
# 2025-12-01 23:34:24.682455
# ####  CLUSTERING  ####
# The best inertia =  76722.91577153819
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.274961
#
#    Mean value of AI policy by WIS : 84.462481
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.842822
#
#    Mean value of AI policy by WIS : 84.668238
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  14
# 2025-12-01 23:36:10.713977
# ####  CLUSTERING  ####
# The best inertia =  77254.27780113317
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.942610
#
#    Mean value of AI policy by WIS : 87.252261
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.938244
#
#    Mean value of AI policy by WIS : 58.623697
#
# ########################   MODEL NUMBER :  15
# 2025-12-01 23:37:51.042901
# ####  CLUSTERING  ####
# The best inertia =  76420.254951835
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.549062
#
#    Mean value of AI policy by WIS : 87.863449
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.371432
#
#    Mean value of AI policy by WIS : 91.101310
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  16
# 2025-12-01 23:39:34.905798
# ####  CLUSTERING  ####
# The best inertia =  77597.55482101528
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.124551
#
#    Mean value of AI policy by WIS : 93.474844
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.779666
#
#    Mean value of AI policy by WIS : 91.214594
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# Best policy was replaced => 95% LB is  90.47855755417069
# ########################   MODEL NUMBER :  17
# 2025-12-01 23:41:20.464752
# ####  CLUSTERING  ####
# The best inertia =  76081.0675024337
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.398012
#
#    Mean value of AI policy by WIS : 84.460227
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.531254
#
#    Mean value of AI policy by WIS : 73.028939
#
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  18
# 2025-12-01 23:43:02.913140
# ####  CLUSTERING  ####
# The best inertia =  77188.03378462265
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.604771
#
#    Mean value of AI policy by WIS : 83.301342
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 55.694999
#
#    Mean value of AI policy by WIS : 91.401110
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  19
# 2025-12-01 23:44:47.561826
# ####  CLUSTERING  ####
# The best inertia =  76590.59258168057
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.638867
#
#    Mean value of AI policy by WIS : 81.039517
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.607991
#
#    Mean value of AI policy by WIS : 90.213577
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  20
# 2025-12-01 23:46:32.339519
# ####  CLUSTERING  ####
# The best inertia =  77246.27319294956
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.937460
#
#    Mean value of AI policy by WIS : 88.292304
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.473501
#
#    Mean value of AI policy by WIS : 89.640329
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  21
# 2025-12-01 23:48:17.568233
# ####  CLUSTERING  ####
# The best inertia =  77185.65453022976
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.094148
#
#    Mean value of AI policy by WIS : 93.792625
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.685266
#
#    Mean value of AI policy by WIS : 63.419065
#
# ########################   MODEL NUMBER :  22
# 2025-12-01 23:50:02.807912
# ####  CLUSTERING  ####
# The best inertia =  77459.03496151979
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.423436
#
#    Mean value of AI policy by WIS : 96.312452
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.969841
#
#    Mean value of AI policy by WIS : 63.457017
#
# ########################   MODEL NUMBER :  23
# 2025-12-01 23:51:47.800876
# ####  CLUSTERING  ####
# The best inertia =  77696.60128970927
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.412278
#
#    Mean value of AI policy by WIS : 83.214076
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 53.525972
#
#    Mean value of AI policy by WIS : 54.095725
#
# ########################   MODEL NUMBER :  24
# 2025-12-01 23:53:36.290683
# ####  CLUSTERING  ####
# The best inertia =  76751.85180892193
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.380810
#
#    Mean value of AI policy by WIS : 89.518692
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 62.502438
#
#    Mean value of AI policy by WIS : 90.170727
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  25
# 2025-12-01 23:55:20.388746
# ####  CLUSTERING  ####
# The best inertia =  77687.0010403652
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.321004
#
#    Mean value of AI policy by WIS : 93.871790
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 60.131237
#
#    Mean value of AI policy by WIS : 87.029717
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  26
# 2025-12-01 23:57:05.580217
# ####  CLUSTERING  ####
# The best inertia =  77739.09365703822
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 57.181901
#
#    Mean value of AI policy by WIS : 84.771910
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 62.663973
#
#    Mean value of AI policy by WIS : 89.963614
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  27
# 2025-12-01 23:58:52.345348
# ####  CLUSTERING  ####
# The best inertia =  76617.97879133564
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.138195
#
#    Mean value of AI policy by WIS : 84.392427
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.367253
#
#    Mean value of AI policy by WIS : 90.193647
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  28
# 2025-12-02 00:00:36.737446
# ####  CLUSTERING  ####
# The best inertia =  78007.67075854819
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.605793
#
#    Mean value of AI policy by WIS : 90.955756
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.745419
#
#    Mean value of AI policy by WIS : 84.078930
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  29
# 2025-12-02 00:02:22.827925
# ####  CLUSTERING  ####
# The best inertia =  77034.22118208667
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.057466
#
#    Mean value of AI policy by WIS : 96.096916
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.455715
#
#    Mean value of AI policy by WIS : 88.986656
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  30
# 2025-12-02 00:04:03.323456
# ####  CLUSTERING  ####
# The best inertia =  77413.21237159093
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 58.956686
#
#    Mean value of AI policy by WIS : 82.974890
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.808422
#
#    Mean value of AI policy by WIS : -38.876235
#
# ########################   MODEL NUMBER :  31
# 2025-12-02 00:05:48.434771
# ####  CLUSTERING  ####
# The best inertia =  78428.71489720032
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.034330
#
#    Mean value of AI policy by WIS : 84.254249
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 60.032388
#
#    Mean value of AI policy by WIS : -7.838067
#
# ########################   MODEL NUMBER :  32
# 2025-12-02 00:07:34.649805
# ####  CLUSTERING  ####
# The best inertia =  77081.8191966294
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 57.947750
#
#    Mean value of AI policy by WIS : 84.416997
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.743529
#
#    Mean value of AI policy by WIS : 89.550020
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  33
# 2025-12-02 00:09:22.242103
# ####  CLUSTERING  ####
# The best inertia =  77019.57549944153
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.884935
#
#    Mean value of AI policy by WIS : 88.263603
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 62.536692
#
#    Mean value of AI policy by WIS : 87.190567
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  34
# 2025-12-02 00:11:06.952875
# ####  CLUSTERING  ####
# The best inertia =  76429.29220856278
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.047290
#
#    Mean value of AI policy by WIS : 92.040883
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.040779
#
#    Mean value of AI policy by WIS : 94.279265
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  35
# 2025-12-02 00:12:49.190233
# ####  CLUSTERING  ####
# The best inertia =  77572.76619128221
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.687511
#
#    Mean value of AI policy by WIS : 90.976259
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.325402
#
#    Mean value of AI policy by WIS : 84.439297
#
# ########################   MODEL NUMBER :  36
# 2025-12-02 00:14:33.930288
# ####  CLUSTERING  ####
# The best inertia =  78029.23618242994
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 58.242782
#
#    Mean value of AI policy by WIS : 92.737079
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 60.408588
#
#    Mean value of AI policy by WIS : -20.002725
#
# ########################   MODEL NUMBER :  37
# 2025-12-02 00:16:19.521423
# ####  CLUSTERING  ####
# The best inertia =  76493.91378414741
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.448746
#
#    Mean value of AI policy by WIS : 89.026449
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.602759
#
#    Mean value of AI policy by WIS : -79.399025
#
# ########################   MODEL NUMBER :  38
# 2025-12-02 00:17:59.960881
# ####  CLUSTERING  ####
# The best inertia =  77859.65793931799
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 58.900329
#
#    Mean value of AI policy by WIS : 92.188082
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.221909
#
#    Mean value of AI policy by WIS : 92.677586
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  39
# 2025-12-02 00:19:45.130642
# ####  CLUSTERING  ####
# The best inertia =  76783.0865238115
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.195002
#
#    Mean value of AI policy by WIS : 85.066942
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.524029
#
#    Mean value of AI policy by WIS : 91.747035
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  40
# 2025-12-02 00:21:27.043816
# ####  CLUSTERING  ####
# The best inertia =  77629.29955623116
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.487738
#
#    Mean value of AI policy by WIS : 91.521628
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.788646
#
#    Mean value of AI policy by WIS : 91.005514
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  41
# 2025-12-02 00:23:14.255126
# ####  CLUSTERING  ####
# The best inertia =  77283.2096249149
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 58.798369
#
#    Mean value of AI policy by WIS : 94.349579
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 62.620891
#
#    Mean value of AI policy by WIS : 80.048014
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  42
# 2025-12-02 00:25:02.459851
# ####  CLUSTERING  ####
# The best inertia =  77264.67525131642
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.455628
#
#    Mean value of AI policy by WIS : 83.732446
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 60.610893
#
#    Mean value of AI policy by WIS : 86.034128
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  43
# 2025-12-02 00:26:46.050474
# ####  CLUSTERING  ####
# The best inertia =  77120.72834778739
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.754014
#
#    Mean value of AI policy by WIS : 82.766562
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 60.274486
#
#    Mean value of AI policy by WIS : 94.184836
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  44
# 2025-12-02 00:28:33.808139
# ####  CLUSTERING  ####
# The best inertia =  76522.39595992203
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.769471
#
#    Mean value of AI policy by WIS : 83.119343
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.307397
#
#    Mean value of AI policy by WIS : 85.994789
#
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  45
# 2025-12-02 00:30:17.690580
# ####  CLUSTERING  ####
# The best inertia =  77006.92251742301
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.926872
#
#    Mean value of AI policy by WIS : 80.739141
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.142997
#
#    Mean value of AI policy by WIS : 85.483762
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  46
# 2025-12-02 00:32:04.463149
# ####  CLUSTERING  ####
# The best inertia =  77269.1262275026
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.985853
#
#    Mean value of AI policy by WIS : 92.114673
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.756086
#
#    Mean value of AI policy by WIS : 83.943697
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  47
# 2025-12-02 00:33:51.112563
# ####  CLUSTERING  ####
# The best inertia =  77272.08785798974
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.463201
#
#    Mean value of AI policy by WIS : 85.298301
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 60.078853
#
#    Mean value of AI policy by WIS : 87.545929
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  48
# 2025-12-02 00:35:36.982423
# ####  CLUSTERING  ####
# The best inertia =  77234.76171956664
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.184386
#
#    Mean value of AI policy by WIS : 84.812553
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.471876
#
#    Mean value of AI policy by WIS : 87.548862
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  49
# 2025-12-02 00:37:22.859985
# ####  CLUSTERING  ####
# The best inertia =  78354.51884687628
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.206556
#
#    Mean value of AI policy by WIS : 77.833288
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.742552
#
#    Mean value of AI policy by WIS : 87.691353
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  50
# 2025-12-02 00:39:08.959753
# ####  CLUSTERING  ####
# The best inertia =  77415.54364943714
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.477610
#
#    Mean value of AI policy by WIS : 90.270327
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.472682
#
#    Mean value of AI policy by WIS : 88.263367
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  51
# 2025-12-02 00:40:51.462202
# ####  CLUSTERING  ####
# The best inertia =  78097.85809237977
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.675816
#
#    Mean value of AI policy by WIS : 87.877077
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.024486
#
#    Mean value of AI policy by WIS : 91.068754
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  52
# 2025-12-02 00:42:38.084518
# ####  CLUSTERING  ####
# The best inertia =  76667.6028916038
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.528506
#
#    Mean value of AI policy by WIS : 85.045981
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 60.397254
#
#    Mean value of AI policy by WIS : 86.052627
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  53
# 2025-12-02 00:44:23.510130
# ####  CLUSTERING  ####
# The best inertia =  77528.75019614559
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.009172
#
#    Mean value of AI policy by WIS : 85.316130
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.475430
#
#    Mean value of AI policy by WIS : 76.188527
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  54
# 2025-12-02 00:46:08.105907
# ####  CLUSTERING  ####
# The best inertia =  76811.88609333838
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.134609
#
#    Mean value of AI policy by WIS : 83.047924
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.994687
#
#    Mean value of AI policy by WIS : 88.496724
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  55
# 2025-12-02 00:47:54.512967
# ####  CLUSTERING  ####
# The best inertia =  77440.17208502122
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.835305
#
#    Mean value of AI policy by WIS : 83.889291
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.099536
#
#    Mean value of AI policy by WIS : 87.627546
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  56
# 2025-12-02 00:49:42.104817
# ####  CLUSTERING  ####
# The best inertia =  78664.92513131845
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.583070
#
#    Mean value of AI policy by WIS : 92.418728
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.253853
#
#    Mean value of AI policy by WIS : 77.017834
#
# ########################   MODEL NUMBER :  57
# 2025-12-02 00:51:21.871308
# ####  CLUSTERING  ####
# The best inertia =  78195.57971667509
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.499991
#
#    Mean value of AI policy by WIS : 73.149627
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.280107
#
#    Mean value of AI policy by WIS : 58.623902
#
# ########################   MODEL NUMBER :  58
# 2025-12-02 00:53:01.011958
# ####  CLUSTERING  ####
# The best inertia =  77464.63438362429
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.890370
#
#    Mean value of AI policy by WIS : 84.514553
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.135045
#
#    Mean value of AI policy by WIS : 81.793890
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  59
# 2025-12-02 00:54:38.845335
# ####  CLUSTERING  ####
# The best inertia =  76278.63289023722
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.829470
#
#    Mean value of AI policy by WIS : 92.529504
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.489009
#
#    Mean value of AI policy by WIS : 83.207705
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  60
# 2025-12-02 00:56:24.425709
# ####  CLUSTERING  ####
# The best inertia =  77992.205720001
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.653780
#
#    Mean value of AI policy by WIS : 85.550486
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.528234
#
#    Mean value of AI policy by WIS : 90.054435
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  61
# 2025-12-02 00:58:08.231810
# ####  CLUSTERING  ####
# The best inertia =  77716.30499087476
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.793711
#
#    Mean value of AI policy by WIS : 86.159445
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.598662
#
#    Mean value of AI policy by WIS : 88.973090
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ...
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.676147
#
#    Mean value of AI policy by WIS : 83.577223
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.203888
#
#    Mean value of AI policy by WIS : 89.856961
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  479
# 2025-12-02 14:09:05.426864
# ####  CLUSTERING  ####
# The best inertia =  76640.75014047095
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.195178
#
#    Mean value of AI policy by WIS : 83.225477
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 54.504474
#
#    Mean value of AI policy by WIS : 88.679811
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  480
# 2025-12-02 14:10:44.867225
# ####  CLUSTERING  ####
# The best inertia =  76743.70520144039
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.971665
#
#    Mean value of AI policy by WIS : 81.471971
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.816473
#
#    Mean value of AI policy by WIS : 74.153727
#
# ########################   MODEL NUMBER :  481
# 2025-12-02 14:12:47.109756
# ####  CLUSTERING  ####
# The best inertia =  75820.50796657465
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.403549
#
#    Mean value of AI policy by WIS : 88.084880
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.451223
#
#    Mean value of AI policy by WIS : 88.641441
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  482
# 2025-12-02 14:14:59.561733
# ####  CLUSTERING  ####
# The best inertia =  77308.5877742701
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.908883
#
#    Mean value of AI policy by WIS : 86.799412
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.821497
#
#    Mean value of AI policy by WIS : 67.760978
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  483
# 2025-12-02 14:16:46.953839
# ####  CLUSTERING  ####
# The best inertia =  76854.8185688887
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.324309
#
#    Mean value of AI policy by WIS : 84.915163
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.798209
#
#    Mean value of AI policy by WIS : 89.684387
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  484
# 2025-12-02 14:18:30.962448
# ####  CLUSTERING  ####
# The best inertia =  75800.82234987509
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.446783
#
#    Mean value of AI policy by WIS : 96.603741
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.792635
#
#    Mean value of AI policy by WIS : 85.858551
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  485
# 2025-12-02 14:20:17.061418
# ####  CLUSTERING  ####
# The best inertia =  77239.28094086485
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.442245
#
#    Mean value of AI policy by WIS : 83.744742
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.143678
#
#    Mean value of AI policy by WIS : 43.834283
#
# ########################   MODEL NUMBER :  486
# 2025-12-02 14:22:13.414010
# ####  CLUSTERING  ####
# The best inertia =  77869.4801110199
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.621303
#
#    Mean value of AI policy by WIS : 86.971902
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.220314
#
#    Mean value of AI policy by WIS : 19.866427
#
# ########################   MODEL NUMBER :  487
# 2025-12-02 14:23:58.249666
# ####  CLUSTERING  ####
# The best inertia =  77803.23961799004
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.020811
#
#    Mean value of AI policy by WIS : 93.512108
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.883816
#
#    Mean value of AI policy by WIS : 90.392926
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  488
# 2025-12-02 14:25:41.234463
# ####  CLUSTERING  ####
# The best inertia =  76921.55782136104
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.894234
#
#    Mean value of AI policy by WIS : 93.572526
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 57.761934
#
#    Mean value of AI policy by WIS : 79.474082
#
# ########################   MODEL NUMBER :  489
# 2025-12-02 14:27:34.355797
# ####  CLUSTERING  ####
# The best inertia =  78130.48555983134
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 58.957942
#
#    Mean value of AI policy by WIS : 96.362493
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.545142
#
#    Mean value of AI policy by WIS : 76.014199
#
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  490
# 2025-12-02 14:29:31.104131
# ####  CLUSTERING  ####
# The best inertia =  76917.42804682179
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.711364
#
#    Mean value of AI policy by WIS : 77.809961
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 54.974887
#
#    Mean value of AI policy by WIS : 88.630436
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  491
# 2025-12-02 14:31:14.284063
# ####  CLUSTERING  ####
# The best inertia =  76990.6947208319
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 60.383252
#
#    Mean value of AI policy by WIS : 83.264506
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.124164
#
#    Mean value of AI policy by WIS : -78.509004
#
# ########################   MODEL NUMBER :  492
# 2025-12-02 14:32:59.199995
# ####  CLUSTERING  ####
# The best inertia =  77363.63856012054
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.270394
#
#    Mean value of AI policy by WIS : 91.676892
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.239878
#
#    Mean value of AI policy by WIS : 82.949076
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  493
# 2025-12-02 14:34:47.365148
# ####  CLUSTERING  ####
# The best inertia =  75255.42504535688
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 61.085091
#
#    Mean value of AI policy by WIS : 83.325764
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.753297
#
#    Mean value of AI policy by WIS : 88.888438
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  494
# 2025-12-02 14:36:33.745937
# ####  CLUSTERING  ####
# The best inertia =  77489.92442984348
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.867809
#
#    Mean value of AI policy by WIS : 85.288654
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 58.953382
#
#    Mean value of AI policy by WIS : 47.893613
#
# ########################   MODEL NUMBER :  495
# 2025-12-02 14:38:59.253227
# ####  CLUSTERING  ####
# The best inertia =  77847.41667640835
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 58.319539
#
#    Mean value of AI policy by WIS : 84.049312
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 60.006264
#
#    Mean value of AI policy by WIS : 63.574419
#
# ########################   MODEL NUMBER :  496
# 2025-12-02 14:41:11.663232
# ####  CLUSTERING  ####
# The best inertia =  76508.26642518539
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 58.712651
#
#    Mean value of AI policy by WIS : 90.128718
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 59.492271
#
#    Mean value of AI policy by WIS : 66.114744
#
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  497
# 2025-12-02 14:43:30.149436
# ####  CLUSTERING  ####
# The best inertia =  75852.89346829947
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.807513
#
#    Mean value of AI policy by WIS : 91.916490
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 56.596216
#
#    Mean value of AI policy by WIS : 68.713634
#
# ########################   MODEL NUMBER :  498
# 2025-12-02 14:45:51.103366
# ####  CLUSTERING  ####
# The best inertia =  76450.76013335749
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 59.897100
#
#    Mean value of AI policy by WIS : 96.212060
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 55.684411
#
#    Mean value of AI policy by WIS : 84.668507
#
# ########################## eICU TEST SET #############################
# ####   GOOD MODEL FOUND - SAVING IT   ####
# ########################   MODEL NUMBER :  499
# 2025-12-02 14:48:12.601717
# ####  CLUSTERING  ####
# The best inertia =  78009.17747841046
# ####  CREATE ACTIONS  ####
# ####  CREATE QLDATA3  ####
# ####  CREATE TRANSITION MATRIX T(S'',S,A) ####
# ####  CREATE TRANSITION MATRIX T(S,S'',A)  ####
# ####  CREATE REWARD MATRIX  R(S,A) ####
# ####  POLICY ITERATION   ####
# ####  OFF-POLICY EVALUATION - MIMIC TRAIN SET ####
#    Mean value of physicians policy by TD Learning : 62.124601
#
#    Mean value of AI policy by WIS : 84.052345
#
# ####  OFF-POLICY EVALUATION - MIMIC TEST SET ####
#    Mean value of physicians policy by TD Learning : 61.543776
#
#    Mean value of AI policy by WIS : -24.874044
